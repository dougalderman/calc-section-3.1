# %%
#Problem_57

# %%
x = var('x')

# %%
def g(x): return exp((1/2)*x)

# %%
d = derivative (g(x), x)

# %%
d
# Out:
# 1/2*e^(1/2*x)

# %%
d2 = derivative(g(x), x, 2)

# %%
d2
# Out:
# 1/4*e^(1/2*x)

# %%
p = []

# %%
p.append(plot(g(x),(x,-3,3), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-3,3), color='red', legend_label='d(g(x))/dx'))

# %%
p.append(plot(d2,(x,-3,3), color='green', legend_label='d2(g(x))/dx2'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem_61

# %%
def F(x): return -exp((1/3)*x)

# %%
d = derivative(F(x), x)

# %%
d
# Out:
# -1/3*e^(1/3*x)

# %%
d2 = derivative(F(x), x, 2)

# %%
d2
# Out:
# -1/9*e^(1/3*x)

# %%
p = []

# %%
p.append(plot(F(x),(x,-3,3), color='blue', legend_label='F(x)'))

# %%
p.append(plot(d,(x,-3,3), color='red', legend_label='d(F(x))/dx'))

# %%
p.append(plot(d2,(x,-3,3), color='green', legend_label='d2(F(x))/dx2'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Problem_75

# %%
def f(x): return exp(x)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# e^x

# %%
def der(x): return exp(x)

# %%
der(0)
# Out:
# 1

# %%
p = []

# %%
p.append(plot(f(x),(x,-3,3), color='blue', legend_label='f(x)'))

# %%
p.append(plot(x+1,(x,-3,3), color='red', legend_label='tangent line at point (0, 1)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problems_83_and_84

# %%
def T(x): return 5200/(1 + 16.3*exp(-0.7*x))

# %%
T(11)
# Out:
# 5161.89959026817

# %%
T(16)
# Out:
# 5198.84123341826

# %%
T(1000)
# Out:
# 5200.00000000000

# %%
d = derivative(T(x), x)

# %%
d
# Out:
# 59332.0000000000*e^(-0.700000000000000*x)/(16.3000000000000*e^(-0.700000000000000*x) + 1)^2

# %%
def der(x): return 59332.0000000000*e^(-0.700000000000000*x)/(16.3000000000000*e^(-0.700000000000000*x) + 1)^2

# %%
der(15)
# Out:
# 1.63232696323580

# %%
#Problems_90_and_91

# %%
t = var('t')

# %%
def D(t): return 34.4 - 30.48/(1+29.44*exp(-0.072*t))

# %%
D(110)
# Out:
# 4.24264045599044

# %%
D(150)
# Out:
# 3.93829412413091

# %%
D(1000)
# Out:
# 3.92000000000000

# %%
d = derivative(D(t), t)

# %%
d
# Out:
# -64.6078464000000*e^(-0.0720000000000000*t)/(29.4400000000000*e^(-0.0720000000000000*t) + 1)^2

# %%
def der(t): return -64.6078464000000*e^(-0.0720000000000000*t)/(29.4400000000000*e^(-0.0720000000000000*t) + 1)^2

# %%
der(109)
# Out:
# -0.0246611168672525

# %%
#Problem_103

# %%
def f(x): return (exp(x) - exp(-x))/(exp(x) + exp(-x))

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -(e^(-x) - e^x)^2/(e^(-x) + e^x)^2 + 1

# %%
(exp(x) + exp(-x))^2 - (exp(x) - exp(-x))^2 == 4
# Out:
# (e^(-x) + e^x)^2 - (e^(-x) - e^x)^2 == 4

# %%
#Problem_111

# %%
def f(x): return (x^2)*exp(-x)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# -x^2*e^(-x) + 2*x*e^(-x)

# %%
d.roots()
# Out:
# [(0, 1), (2, 1)]

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# x^2*e^(-x) - 4*x*e^(-x) + 2*e^(-x)

# %%
def der2(x): return x^2*e^(-x) - 4*x*e^(-x) + 2*e^(-x)

# %%
der2(0)
# Out:
# 2

# %%
der2(2)
# Out:
# -2*e^(-2)

# %%
f(0)
# Out:
# 0

# %%
f(2)
# Out:
# 4*e^(-2)

# %%
numerical_approx(4*e^(-2))
# Out:
# 0.541341132946451

# %%
d2.roots()
# Out:
# [(-sqrt(2) + 2, 1), (sqrt(2) + 2, 1)]

# %%
numerical_approx(-sqrt(2) + 2)
# Out:
# 0.585786437626905

# %%
numerical_approx(sqrt(2) + 2)
# Out:
# 3.41421356237309

# %%
der2(-1)
# Out:
# 7*e

# %%
der2(4)
# Out:
# 2*e^(-4)

# %%
f(-sqrt(2) + 2)
# Out:
# (sqrt(2) - 2)^2*e^(sqrt(2) - 2)

# %%
f(sqrt(2) + 2)
# Out:
# (sqrt(2) + 2)^2*e^(-sqrt(2) - 2)

# %%
numerical_approx((sqrt(2) - 2)^2*e^(sqrt(2) - 2))
# Out:
# 0.191018226056977

# %%
numerical_approx((sqrt(2) + 2)^2*e^(-sqrt(2) - 2))
# Out:
# 0.383536990512539

# %%
p = []

# %%
p.append(plot(f(x),(x,-1,6), ymin=-3, color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-1,6), ymin=-3, color='red', legend_label='d(f(x))/d(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem_115

# %%
def f(x): return 2*exp(0.3*x)

# %%
d = derivative(f(x), x)

# %%
d
# Out:
# 0.600000000000000*e^(0.300000000000000*x)

# %%
d2 = derivative(f(x), x, 2)

# %%
d2
# Out:
# 0.180000000000000*e^(0.300000000000000*x)

# %%
d.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-d6ece07eb299> in <module>
# ----> 1 d.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
d2.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-9e801c8d3494> in <module>
# ----> 1 d2.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
p = []

# %%
p.append(plot(f(x),(x,-3,3), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-3,3), color='red', legend_label='d(f(x))/d(x)'))

# %%
p.append(plot(d2,(x,-3,3), color='green', legend_label='d2(f(x))/d(x2)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives
